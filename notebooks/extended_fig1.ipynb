# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
import time

# %%
import sys
sys.path.append("../code")
import model_agegroups
import plotting
import plotting_agegroups
import parameters_agegroups
import cosmodata

# %%
#CosmoStringency, CosmoICU, CosmovsICU, KernelR, KernelV, Romania, Willingness, Vaccination

motivation = {
    'ax1': 'CosmoICU',
    'ax2': 'CosmovsICU',
    'ax3': 'ContactFeedback',
    'ax4': 'Romania',
    'ax5': 'Willingness',
    'ax6': 'Vaccination',

    'cICU': '#00468BFF',
    'cStringency': 'orange',
    'cCosmodata': 'red',
    'cVaccines': '#0099B4FF',
    'cFit': 'black',
    'cVac1': '#10750FFF',
    'cVac2': '#70AC6FFF',
}

# %%
import importlib
importlib.reload(plotting_agegroups)
plotting_agegroups.motivation(motivation, arial=True)
# Out:
# Linear correlation: 0.6996061003210295
# Linear correlation: 0.7647960362312388
# Parameters: [0.83752604 0.0053294 ]
# One standard deviation: [0.01835087 0.00094654]
# Relative error: [0.02191081 0.17760685]
